# %% [markdown]
# # Работа с Excel

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 7: Работа с Excel
# * https://docs.xlwings.org/en/stable/quickstart.html
# * https://nbviewer.jupyter.org/github/pybokeh/jupyter_notebooks/blob/master/xlwings/Excel_Formatting.ipynb#search_text

# %%
import xlwings as xw
import pandas as pd
import numpy as np

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. На листе "Рецептура" файла `себестоимостьА_в1.xlsx` для области "Пшеничный хлеб" рассчитать себестоимость всех видов продукции.

# %% [markdown]
# 2. Результаты расчетов 1.1 сохранить в отдельном столбце области "Пшеничный хлеб"

# %% [markdown]
# 3. Приблизить форматирование столбца, добавленного в задаче 2 к оформлению всей области.

# %% [markdown]
# 4. Выполнить 3 с помощью "протягиваемых" формул.

# %% [markdown]
# ## Лабораторная работа 7

# %% [markdown]
# 1. Загрузите данные из файлов `reviews_sample.csv` (__ЛР2__) и `recipes_sample_with_tags_ingredients.csv` (__ЛР5__) в виде `pd.DataFrame`. Обратите внимание на корректное считывание столбца(ов) с индексами. Оставьте в таблице с рецептами следующие столбцы: `id`, `name`, `minutes`, `submitted`, `description`, `n_ingredients`

# %%
recipes_sample_with_tags_ingredients = pd.read_csv("C:\datasets/recipes_sample_with_tags_ingredients.csv")
recipes_sample_with_tags_ingredients = recipes_sample_with_tags_ingredients.rename(columns={"Unnamed: 0": "index"})
recipes_sample_with_tags_ingredients = recipes_sample_with_tags_ingredients.set_index("index")
recipes_sample_with_tags_ingredients= recipes_sample_with_tags_ingredients[["id", "name", "minutes", "submitted", "description", "n_ingredients"]]
recipes_sample_with_tags_ingredients.head()
# Out:
#           id                                      name  minutes   submitted  \
# index
# 0      44123     george s at the cove  black bean soup       90  2002-10-25
# 1      67664        healthy for them  yogurt popsicles       10  2003-07-26
# 2      38798              i can t believe it s spinach       30  2002-08-29
# 3      35173                      italian  gut busters       45  2002-07-27
# 4      84797  love is in the air  beef fondue   sauces       25  2004-02-23
#
#                                              description  n_ingredients
# index
# 0      an original recipe created by chef scott meska...             18
# 1      my children and their friends ask for my homem...              6
# 2                these were so go, it surprised even me.             14
# 3      my sister-in-law made these for us at a family...              8
# 4      i think a fondue is a very romantic casual din...              4

# %%
reviews_sample = pd.read_csv("C:\datasets/reviews_sample.csv")
reviews_sample = reviews_sample.rename(columns={"Unnamed: 0": "index"})
reviews_sample = reviews_sample.set_index("index")
reviews_sample.head()
# Out:
#            user_id  recipe_id        date  rating  \
# index
# 370476       21752      57993  2003-05-01       5
# 624300      431813     142201  2007-09-16       5
# 187037      400708     252013  2008-01-10       4
# 706134  2001852463     404716  2017-12-11       5
# 312179       95810     129396  2008-03-14       5
#
#                                                    review
# index
# 370476  Last week whole sides of frozen salmon fillet ...
# 624300  So simple and so tasty!  I used a yellow capsi...
# 187037  Very nice breakfast HH, easy to make and yummy...
# 706134  These are a favorite for the holidays and so e...
# 312179  Excellent soup!  The tomato flavor is just gre...

# %% [markdown]
# 2. Случайным образом выберите 5% строк из каждой таблицы и сохраните две таблицы на разные листы в один файл `recipes.xlsx`. Дайте листам названия "Рецепты" и "Отзывы", соответствующие содержанию таблиц.

# %%
reviews_sample_new = reviews_sample.sample(round(reviews_sample.shape[0]*0.05))

# %%
recipes_sample_with_tags_ingredients_new = recipes_sample_with_tags_ingredients.sample(round(recipes_sample_with_tags_ingredients.shape[0]*0.05))

# %%
 recipes_sample_with_tags_ingredients_new
# Out:
#            id                                               name  minutes  \
# index
# 2170   357270                              banana nut snack bars       70
# 21093  312160                                pom orange smoothie        5
# 19274   95582                          orange   rosemary chicken       45
# 26479  504308                super simple smoked salmon crostini       25
# 17      95534                da best  chicago style italian beef      645
# ...       ...                                                ...      ...
# 4787    64398                                carol s garlic ribs       80
# 7303   351572                        coconut milk braised greens       20
# 12085  285107             glazed asparagus   carrots with pecans       30
# 27719   69250                         tofu lasagna    no noodles      105
# 27425  365639  the easiest  best chocolate chip peanut butter...       16
#
#         submitted                                        description  \
# index
# 2170   2009-02-22  i found this recipe on the www.cheerios.com we...
# 21093  2008-07-05  you know the smoothie drill- toss it all in th...
# 19274  2004-07-14                                  from bon appetit.
# 26479  2013-07-19  this recipe comes from real simple (and it is ...
# 17     2004-07-13  tender, garlicky and full of oregano 'n stuff!...
# ...           ...                                                ...
# 4787   2003-06-12  this has been a favorite in our family for yea...
# 7303   2009-01-23  recipe from whole foods.  states, "creamy coco...
# 12085  2008-02-08  a lemon glaze tops a springtime combination of...
# 27719  2003-08-21  this is a yummy vegetarian, lo-carb, lo-cal di...
# 27425  2009-04-12  this is a recipe my mother has been using for ...
#
#        n_ingredients
# index
# 2170               6
# 21093              5
# 19274             12
# 26479             12
# 17                 9
# ...              ...
# 4787              11
# 7303              12
# 12085              7
# 27719              3
# 27425              6
#
# [1500 rows x 6 columns]

# %%
wb = xw.Book('C:\datasets/recipes.xlsx')

# %%
#recipy= wb.sheets.add(name="Рецепты")
#sheet = xw.sheets.add(name="Отзывы")

recipy.range('A1').value = recipes_sample_with_tags_ingredients_new
sheet.range('A1').value = reviews_sample_new

# %% [markdown]
# 3. Используя `xlwings`, добавьте на лист `Рецепты` столбец `seconds_assign`, показывающий время выполнения рецепта в секундах. Выполните задание при помощи присваивания массива значений диапазону ячеек.

# %%
recipes_sample_with_tags_ingredients_new_aa = (recipes_sample_with_tags_ingredients_new["minutes"]*60).tolist()

# %%
recipes_sample_with_tags_ingredients_new_aa
# Out:
# [4200,
#  300,
#  2700,
#  1500,
#  38700,
#  5700,
#  4200,
#  120,
#  2100,
#  1500,
#  660,
#  0,
#  2100,
#  1800,
#  120,
#  300,
#  3600,
#  300,
#  900,
#  360,
#  300,
#  3900,
#  2700,
#  1500,
#  1500,
#  900,
#  2040,
#  1920,
#  1800,
#  600,
#  600,
#  300,
#  1200,
#  2400,
#  2400,
#  4800,
#  5400,
#  3600,
#  2100,
#  300,
#  1020,
#  360,
#  3300,
#  480,
#  1200,
#  600,
#  1200,
#  2400,
#  900,
#  36600,
#  4200,
#  3000,
#  1200,
#  1800,
#  300,
#  1500,
#  1740,
#  2100,
#  1500,
#  3300,
#  22500,
#  300,
#  1500,
#  29700,
#  3300,
#  900,
#  62400,
#  3180,
#  29100,
#  1800,
#  3300,
#  1500,
#  600,
#  840,
#  2100,
#  2400,
#  7800,
#  4200,
#  2400,
#  2700,
#  4800,
#  22500,
#  900,
#  2700,
#  2400,
#  1680,
#  300,
#  1800,
#  7200,
#  1200,
#  4800,
#  2400,
#  2400,
#  1500,
#  2100,
#  1200,
#  2100,
#  5400,
#  2400,
#  2400,
#  2400,
#  900,
#  3600,
#  2700,
#  3600,
#  3300,
#  3600,
#  3900,
#  2100,
#  900,
#  3600,
#  1800,
#  1800,
#  1080,
#  300,
#  3600,
#  8160,
#  5400,
#  3900,
#  4200,
#  2100,
#  180,
#  900,
#  2100,
#  600,
#  900,
#  1260,
#  300,
#  600,
#  3900,
#  4500,
#  1500,
#  2400,
#  260400,
#  900,
#  87000,
#  2700,
#  3900,
#  2400,
#  3600,
#  600,
#  3600,
#  1800,
#  1200,
#  1800,
#  3600,
#  1800,
#  4200,
#  3900,
#  7200,
#  4500,
#  3600,
#  1500,
#  3000,
#  300,
#  3600,
#  3900,
#  1500,
#  4200,
#  600,
#  7800,
#  1500,
#  1200,
#  22500,
#  6000,
#  3000,
#  29700,
#  1980,
#  3300,
#  1200,
#  120,
#  900,
#  600,
#  1200,
#  600,
#  300,
#  9600,
#  900,
#  5100,
#  3600,
#  3000,
#  3000,
#  240,
#  300,
#  1500,
#  1800,
#  120,
#  780,
#  3000,
#  1200,
#  1800,
#  3900,
#  6300,
#  2100,
#  2100,
#  2100,
#  900,
#  4200,
#  1320,
#  300,
#  4800,
#  3600,
#  600,
#  1200,
#  158400,
#  5100,
#  6540,
#  3000,
#  1800,
#  9900,
#  4500,
#  600,
#  0,
#  2700,
#  2700,
#  180,
#  1800,
#  1200,
#  2100,
#  48300,
#  17100,
#  3900,
#  1320,
#  10800,
#  3600,
#  3900,
#  900,
#  36900,
#  600,
#  5700,
#  4200,
#  3600,
#  2400,
#  900,
#  45300,
#  600,
#  1500,
#  1200,
#  3600,
#  1800,
#  2100,
#  12600,
#  4320,
#  7200,
#  1800,
#  22500,
#  3300,
#  2100,
#  600,
#  420,
#  2400,
#  2400,
#  30300,
#  1800,
#  87000,
#  6000,
#  1200,
#  3900,
#  4500,
#  4800,
#  2400,
#  2700,
#  22800,
#  1500,
#  2700,
#  1500,
#  600,
#  600,
#  4800,
#  4800,
#  11100,
#  2400,
#  5700,
#  1200,
#  300,
#  3900,
#  6300,
#  3600,
#  900,
#  2700,
#  3600,
#  180,
#  3600,
#  2700,
#  2100,
#  4200,
#  2700,
#  3000,
#  2700,
#  1500,
#  5400,
#  1200,
#  1500,
#  300,
#  2400,
#  2400,
#  5400,
#  2400,
#  3300,
#  259200,
#  4800,
#  3600,
#  3600,
#  1200,
#  1500,
#  600,
#  300,
#  300,
#  8100,
#  2100,
#  1800,
#  2700,
#  1080,
#  3600,
#  300,
#  5400,
#  3900,
#  3900,
#  900,
#  89100,
#  1500,
#  4800,
#  2400,
#  2700,
#  3300,
#  2100,
#  1800,
#  1800,
#  4800,
#  3900,
#  2700,
#  1800,
#  4500,
#  5100,
#  1680,
#  2400,
#  2700,
#  600,
#  23700,
#  1500,
#  1500,
#  900,
#  3600,
#  3300,
#  1920,
#  1800,
#  15000,
#  720,
#  1080,
#  300,
#  1800,
#  3600,
#  900,
#  2100,
#  3900,
#  900,
#  2100,
#  1200,
#  3300,
#  1500,
#  9000,
#  4500,
#  5400,
#  600,
#  600,
#  3180,
#  13200,
#  9900,
#  1800,
#  300,
#  5700,
#  2100,
#  9000,
#  1800,
#  900,
#  2400,
#  2400,
#  2700,
#  1800,
#  4500,
#  6000,
#  86400,
#  900,
#  420,
#  2400,
#  1800,
#  1800,
#  2700,
#  2400,
#  600,
#  1800,
#  12300,
#  14400,
#  4500,
#  1500,
#  900,
#  120,
#  2700,
#  2100,
#  600,
#  23400,
#  2700,
#  1500,
#  300,
#  300,
#  4500,
#  2100,
#  2700,
#  600,
#  2400,
#  2700,
#  1800,
#  900,
#  4500,
#  4500,
#  5400,
#  3600,
#  12000,
#  360,
#  4200,
#  15300,
#  2100,
#  900,
#  5100,
#  900,
#  2400,
#  720,
#  6000,
#  1800,
#  1200,
#  3600,
#  2100,
#  2100,
#  300,
#  2400,
#  5400,
#  300,
#  7200,
#  4200,
#  600,
#  2400,
#  3300,
#  4200,
#  2400,
#  4800,
#  900,
#  1800,
#  2100,
#  1200,
#  1800,
#  900,
#  900,
#  1500,
#  2100,
#  3000,
#  2400,
#  1800,
#  15600,
#  4800,
#  7200,
#  3300,
#  15600,
#  5100,
#  2400,
#  1500,
#  4500,
#  22200,
#  2700,
#  4200,
#  900,
#  2700,
#  2400,
#  6000,
#  2100,
#  2820,
#  2400,
#  4800,
#  2100,
#  1800,
#  2400,
#  5100,
#  2700,
#  4800,
#  3900,
#  720,
#  0,
#  2400,
#  1200,
#  88800,
#  3000,
#  1800,
#  360,
#  600,
#  1800,
#  1020,
#  300,
#  22800,
#  2100,
#  3000,
#  2700,
#  3600,
#  120,
#  1500,
#  600,
#  1200,
#  2400,
#  5400,
#  2400,
#  900,
#  2400,
#  2100,
#  900,
#  2580,
#  300,
#  3600,
#  1800,
#  6000,
#  3600,
#  2700,
#  600,
#  1200,
#  1020,
#  240,
#  4500,
#  1500,
#  1500,
#  1800,
#  2700,
#  600,
#  300,
#  3600,
#  2280,
#  1038000,
#  3900,
#  1800,
#  300,
#  4500,
#  14400,
#  3000,
#  3300,
#  2100,
#  2100,
#  1800,
#  6300,
#  6000,
#  29100,
#  4200,
#  900,
#  3600,
#  3900,
#  1500,
#  12000,
#  2700,
#  9900,
#  9600,
#  15300,
#  1800,
#  6600,
#  600,
#  2100,
#  1800,
#  600,
#  1200,
#  3000,
#  3600,
#  2700,
#  1860,
#  1500,
#  5400,
#  6900,
#  600,
#  7800,
#  4500,
#  1800,
#  4500,
#  3420,
#  60,
#  480,
#  3600,
#  300,
#  93600,
#  3600,
#  2700,
#  1800,
#  3300,
#  300,
#  1800,
#  1800,
#  5400,
#  1620,
#  2280,
#  12000,
#  2100,
#  3000,
#  480,
#  19800,
#  600,
#  1800,
#  4200,
#  2700,
#  2700,
#  2400,
#  9600,
#  3600,
#  960,
#  1200,
#  900,
#  900,
#  2100,
#  2400,
#  3300,
#  2700,
#  3300,
#  4800,
#  25500,
#  600,
#  1800,
#  3000,
#  2400,
#  900,
#  600,
#  2700,
#  2100,
#  900,
#  2100,
#  1800,
#  12000,
#  3000,
#  4800,
#  4500,
#  2700,
#  1800,
#  1500,
#  9900,
#  14700,
#  21900,
#  2700,
#  1500,
#  3000,
#  2700,
#  1080,
#  19200,
#  600,
#  11400,
#  2100,
#  1800,
#  900,
#  900,
#  2400,
#  2700,
#  4500,
#  600,
#  3300,
#  5400,
#  2700,
#  1500,
#  3000,
#  600,
#  3600,
#  2100,
#  22800,
#  14400,
#  7500,
#  1680,
#  11700,
#  1800,
#  1200,
#  300,
#  9300,
#  1200,
#  2100,
#  9900,
#  300,
#  3000,
#  7740,
#  1500,
#  1200,
#  780,
#  600,
#  4800,
#  1200,
#  2100,
#  3000,
#  3600,
#  17100,
#  22800,
#  2400,
#  1500,
#  2592300,
#  1320,
#  5400,
#  9000,
#  2400,
#  1200,
#  1320,
#  2700,
#  300,
#  1200,
#  2700,
#  1500,
#  900,
#  11400,
#  7200,
#  1800,
#  60,
#  1200,
#  900,
#  2100,
#  2100,
#  2700,
#  1560,
#  30000,
#  300,
#  960,
#  4200,
#  720,
#  720,
#  1200,
#  2700,
#  3000,
#  3000,
#  9000,
#  600,
#  600,
#  2700,
#  600,
#  2100,
#  2400,
#  1200,
#  300,
#  3900,
#  2520,
#  480,
#  3600,
#  1140,
#  300,
#  300,
#  900,
#  3300,
#  600,
#  1800,
#  1200,
#  19800,
#  900,
#  3300,
#  300,
#  2700,
#  3000,
#  2100,
#  11700,
#  6300,
#  360,
#  3000,
#  0,
#  3600,
#  2400,
#  1200,
#  1500,
#  2220,
#  2700,
#  2400,
#  5400,
#  300,
#  4800,
#  2700,
#  1200,
#  600,
#  900,
#  6300,
#  2040,
#  900,
#  2100,
#  4500,
#  89100,
#  1020,
#  900,
#  7800,
#  2100,
#  600,
#  1680,
#  30600,
#  1800,
#  7800,
#  2400,
#  3300,
#  300,
#  1800,
#  1740,
#  3300,
#  2100,
#  4800,
#  2700,
#  3000,
#  3600,
#  1800,
#  1800,
#  3600,
#  2100,
#  360,
#  3000,
#  2700,
#  1320,
#  1800,
#  1500,
#  300,
#  3600,
#  3600,
#  1500,
#  3000,
#  6600,
#  2400,
#  2400,
#  1500,
#  1860,
#  3600,
#  1800,
#  900,
#  3900,
#  1800,
#  3000,
#  3600,
#  3300,
#  600,
#  3300,
#  2400,
#  600,
#  300,
#  3600,
#  6300,
#  4500,
#  1500,
#  7200,
#  480,
#  43800,
#  1200,
#  600,
#  4500,
#  600,
#  87000,
#  7800,
#  4800,
#  7200,
#  2700,
#  3720,
#  1200,
#  1200,
#  3600,
#  2700,
#  2400,
#  120,
#  3900,
#  3900,
#  2100,
#  300,
#  4500,
#  4800,
#  3900,
#  3600,
#  960,
#  300,
#  2100,
#  7800,
#  5700,
#  600,
#  4500,
#  5400,
#  300,
#  1200,
#  3900,
#  1200,
#  1500,
#  300,
#  3000,
#  3900,
#  1020,
#  11400,
#  4500,
#  1800,
#  900,
#  3000,
#  8100,
#  1800,
#  5400,
#  2100,
#  300,
#  2100,
#  5400,
#  18600,
#  4500,
#  5700,
#  5700,
#  1200,
#  5400,
#  3600,
#  600,
#  2400,
#  1800,
#  1200,
#  3000,
#  300,
#  1020,
#  780,
#  720,
#  900,
#  1980,
#  2760,
#  2400,
#  300,
#  2100,
#  1260,
#  7200,
#  5160,
#  4200,
#  1728600,
#  4860,
#  2280,
#  2100,
#  780,
#  1620,
#  4500,
#  900,
#  2400,
#  1500,
#  1200,
#  6000,
#  6600,
#  960,
#  1800,
#  600,
#  5400,
#  1800,
#  8400,
#  600,
#  900,
#  2400,
#  1500,
#  4500,
#  1800,
#  1200,
#  3600,
#  1800,
#  3300,
#  2700,
#  3300,
#  3300,
#  600,
#  4200,
#  3600,
#  1320,
#  900,
#  1920,
#  5100,
#  900,
#  22200,
#  2100,
#  2100,
#  15000,
#  1800,
#  3600,
#  1800,
#  3900,
#  2400,
#  300,
#  1740,
#  2100,
#  1020,
#  1500,
#  4200,
#  1800,
#  2100,
#  1500,
#  2400,
#  3000,
#  10080,
#  1500,
#  7800,
#  1800,
#  2580,
#  1500,
#  900,
#  4200,
#  3000,
#  5400,
#  900,
#  2100,
#  3600,
#  1380,
#  3900,
#  1200,
#  1500,
#  1800,
#  8100,
#  600,
#  4200,
#  600,
#  5400,
#  5400,
#  1500,
#  5100,
#  2400,
#  ...]

# %%
recipy.range('H1').value = "seconds_assign"
recipy.range('H2').options(transpose=True).value = recipes_sample_with_tags_ingredients_new_aa

# %% [markdown]
# 4. Используя `xlwings`, добавьте на лист `Рецепты` столбец `seconds_formula`, показывающий время выполнения рецепта в секундах. Выполните задание при помощи формул Excel.

# %%
wb.sheets[1].activate()

# %%
# задаем формулу:
recipy.range('I1').value = "seconds_formula"
xw.Range('I2').formula = f'=D2*60'

# %%
# импортируем константу:
from xlwings.constants import AutoFillType
# и протягиваем ее:
xw.Range('I2').api.AutoFill(xw.Range("I2:I6336").api,
                               AutoFillType.xlFillDefault)
# Out:
# True

# %% [markdown]
# 5. Добавьте на лист `Рецепты`  столбец `n_reviews`, содержащий кол-во отзывов для этого рецепта. Выполните задание при помощи формул Excel.

# %%
wb.sheets[0].activate()

# %%
sheet.range('H1').value = "n_reviews"

# %%
# задаем формулу:
xw.Range('H2').formula = f'=COUNTIF($D$2:$D$6336; D2)'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-168-d71215fbb379> in <module>
#       1 # задаем формулу:
# ----> 2 xw.Range('H2').formula = f'=COUNTIF($D$2:$D$6336; D2)'
#
# ~\anaconda3\lib\site-packages\xlwings\main.py in formula(self, value)
#    1440     @formula.setter
#    1441     def formula(self, value):
# -> 1442         self.impl.formula = value
#    1443
#    1444     @property
#
# ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py in formula(self, value)
#     811     def formula(self, value):
#     812         if self.xl is not None:
# --> 813             self.xl.Formula = value
#     814
#     815     @property
#
# <string> in __init__(self, *args, **kw)
#
# KeyboardInterrupt:

# %%
# импортируем константу:
from xlwings.constants import AutoFillType
# и протягиваем ее:
xw.Range('H2').api.AutoFill(xw.Range("H2:H6336").api,
                               AutoFillType.xlFillDefault)

# %% [markdown]
# 6. Сделайте названия всех добавленных столбцов полужирными и выровняйте по центру ячейки.

# %%
recipy['H1'].font.bold = True
recipy['I1'].font.bold = True
sheet['H1'].font.bold = True

# %%
wb.sheets[0].activate()
xw.Range('H1').columns.autofit()

# %%
wb.sheets[1].activate()
xw.Range('H1:I1').columns.autofit()

# %% [markdown]
# 7. Раскрасьте ячейки столбца `minutes` в соответствии со следующим правилом: если рецепт выполняется быстрее 5 минут, то цвет - зеленый; от 5 до 10 минут - жёлтый; и больше 10 - красный.

# %%
(recipy.range((2,4)).value)
# Out:
# 11.0

# %%
for i in range(2,len(recipes_sample_with_tags_ingredients_new_aa)+1):
    if int(recipy.range((i,4)).value) <= 5:
        recipy.range((i,4)).color = (0, 255, 0)
    if (5 < int(recipy.range((i,4)).value)) and (10 >= int(recipy.range((i,4)).value)) :   
        recipy.range((i,4)).color = (248,255,1)
    if (10 < int(recipy.range((i,4)).value)):
        recipy.range((i,4)).color = (255,80,0)

# %% [markdown]
# 8. Напишите функцию `validate()`, которая проверяет соответствие всех строк из листа `Отзывы` следующим правилам:
#     * Рейтинг - это число от 0 до 5 включительно
#     * Соответствующий рецепт имеется на листе `Рецепты`
#
# В случае несоответствия этим правилам, выделите строку красным цветом

# %%
sheet.range((1,8)).value
# Out:
# 'n_reviews'

# %%
# %%writefile my_project.py
import xlwings as xw
# @xw.func is a decorator. 
# It must be added right before the def to let xlwings know this is a user-defined function.
@xw.func
def validate(sheet,reviews_sample):
    recipes_sample_with_tags_ingredients_new =  recipes_sample_with_tags_ingredients_new["id"].tolist()
    for i in range(2,len(reviews_sample.shape[0])):
        if (int(sheet.range((i,6)).value) >=0) and ((int(sheet.range((i,6)).value) <=5) and ((int(sheet.range((i,2)).value) in recipes_sample_with_tags_ingredients_new):
            pass
        else:
            for j in range(1,9):
                sheet.range((i,j)).color = (220, 20, 60)
# Out:
# Overwriting my_project.py
